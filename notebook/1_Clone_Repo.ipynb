# %% [markdown]
# # MMVC Trainer - 1. Repository Clone & Setup
#
# このノートブックはMMVC Trainerのセットアップを行います。
#
# ## 1. リポジトリのクローンと依存関係のインストール

# %%
# GPU環境の確認
# !nvidia-smi
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA version: {torch.version.cuda}")
if torch.cuda.is_available():
    print(f"GPU count: {torch.cuda.device_count()}")
    print(f"Current GPU: {torch.cuda.get_device_name()}")

# %%
# MMVC Trainerリポジトリのクローン
import os
if not os.path.exists('/content/MMVC_Trainer'):
    # !git clone https://github.com/your-username/MMVC_Trainer.git /content/MMVC_Trainer
    
# %cd /content/MMVC_Trainer

# %%
# 依存関係のインストール
# !pip install -r requirements.txt

# %%
# Cython拡張のビルド
# !python mmvc_trainer.py --setup

# %% [markdown]
# ## 2. システムチェック

# %%
# システム要件の確認
# !python mmvc_trainer.py

# %% [markdown]
# ## 3. データセットフォルダの作成
#
# 音声データを準備するためのフォルダ構造を作成します。

# %%
# データセットフォルダの作成
import os

dataset_dirs = [
    'dataset/textful/00_myvoice/wavs',
    'dataset/textful/01_target/wavs',
    'fine_model',
    'filelists',
    'logs'
]

for dir_path in dataset_dirs:
    os.makedirs(dir_path, exist_ok=True)
    print(f"Created: {dir_path}")

print("\nDataset structure created successfully!")
print("Please upload your audio files (.wav) and transcripts to:")
print("- dataset/textful/00_myvoice/wavs/ (source voice)")
print("- dataset/textful/01_target/wavs/ (target voice)")
print("- Create transcript.txt files in each speaker folder")

# %% [markdown]
# ## セットアップ完了！
#
# 次のステップ:
# 1. 音声ファイル(.wav)をアップロード
# 2. transcript.txtファイルを作成
# 3. "2. Create_Configfile.ipynb"を実行
